# %%
import cv2
from PIL import Image
import numpy as np

# %%
img = cv2.imread("/work/data/src/Lena.jpg", 0)

# %%
img_canny = cv2.Canny(img, 10, 180)
display(Image.fromarray(img_canny))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FDC8918E650>

# %%
img_canny = cv2.Canny(img, 10, )
display(Image.fromarray(img_canny))
