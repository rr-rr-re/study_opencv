# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("/work/data/src/Lena.jpg")

display(Image.fromarray(img))
#cv2.imshow("img", img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
img.shape
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FB3F724FA90>
# (512, 512, 3)

# %%
color_list = ['blue', 'green', 'red']
for i, j in enumerate(color_list):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist, color = j)

# %%
img_gray = cv2.imread("/work/data/src/Lena.jpg", 0)
hist2 = cv2.calcHist([img_gray], [0], None, [256], [0, 256])
plt.plot(hist2)
