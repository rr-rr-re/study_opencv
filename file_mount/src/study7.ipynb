# %%
import cv2
from PIL import Image
import numpy as np

# %%
img = cv2.imread("/work/data/src/grapes.jpg")
h, w = img.shape[:2]
dx, dy = 30, 30

# %%
afn_mat = np.float32([[1, 0, dx], [0, 1, dy]])
img_afn = cv2.warpAffine(img, afn_mat, (h, w))

# %%
display(Image.fromarray(img_afn))
# Out:
# <PIL.Image.Image image mode=RGB size=640x960 at 0x7FF5D0FD6E90>

# %%
rot_mat = cv2.getRotationMatrix2D((w/2, h/2), 40, 1)
img_afn2 = cv2.warpAffine(img, rot_mat, (w, h))

# %%
display(Image.fromarray(img_afn2))
# Out:
# <PIL.Image.Image image mode=RGB size=960x640 at 0x7FF5CF143090>
