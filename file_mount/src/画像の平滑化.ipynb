# %%
import cv2
from PIL import Image
import numpy as np

# %%
img = cv2.imread("/work/data/src/buildings.jpg")

# %%
img_blur = cv2.blur(img, (3, 3))

# %%
display(Image.fromarray(img))
display(Image.fromarray(img_blur))
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F028E509F50>
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F028E517AD0>

# %%
img_ga = cv2.GaussianBlur(img, (9, 9), 2)

# %%
display(Image.fromarray(img))
display(Image.fromarray(img_ga))
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F028E440750>
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F028E440610>

# %%
img_me = cv2.medianBlur(img, 5)

# %%
display(Image.fromarray(img))
display(Image.fromarray(img_me))
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F028E440090>
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F028C339DD0>

# %%
img_bi = cv2.bilateralFilter(img, 20, 30, 30)

# %%
display(Image.fromarray(img))
diaplay(Imgae.fromarray(img_bi))
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F028C2F6B50>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-376f86f15874> in <module>
#       1 display(Image.fromarray(img))
# ----> 2 diaplay(Imgae.fromarray(img_bi))
#
# NameError: name 'diaplay' is not defined
