# %%
import cv2
from PIL import Image
import numpy as np

# %%
img =cv2.imread("/work/data/src/drive.jpg")
h, w = img.shape[:2]
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F74DCC1E610>

# %%
per1 = np.float32([[100, 500], [300, 500], [300, 100], [100, 100]])
per2 = np.float32([[100, 500], [300, 500], [280, 200], [150, 200]])

psp_matrix = cv2.getPerspectiveTransform(per1, per2)
img_psp = cv2.warpPerspective(img, psp_matrix, (w, h))

# %%
display(Image.fromarray(img_psp))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F74DCB50450>
