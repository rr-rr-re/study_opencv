# %%
import cv2
from PIL import Image
import numpy as np

# %%
kernel = np.ones((3, 3)) / 9.0
kernel
# Out:
# array([[0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111]])

# %%
img = cv2.imread("/work/data/src/Lena.jpg", 0)

# %%
img_ke1 = cv2.filter2D(img, -1, kernel)

# %%
display(Image.fromarray(img))
display(Image.fromarray(img_ke1))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F82A3EF1790>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F82A3EF1750>

# %%
kernel2 =np.zeros((3, 3))
kernel2[0,0] = 1
kernel2[1,0] = 2
kernel2[2,0] = 1
kernel2[0,2] = -1
kernel2[1,2] = -2
kernel2[2,2] = -1

# %%
kernel2
# Out:
# array([[ 1.,  0., -1.],
#        [ 2.,  0., -2.],
#        [ 1.,  0., -1.]])

# %%
img_kernel2 = cv2.filter2D(img, -1, kernel2)
display(Image.fromarray(img_kernel2))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F82A3EF1DD0>
